# %% [markdown]
# # TP5 - Visualisation sous `Python`
#
# #### Analyse de Données Massives - Master 1ère année
#
# Dans ce TP, nous allons utiliser les packages [`bokeh`](http://bokeh.pydata.org) et [`seaborn`](https://seaborn.pydata.org). Comme d'habitude, il faut tout d'abord installer les modules via un terminale de commande. Le module `pydataset` contient,lui, plusieurs jeux de données que nous allons utiliser.
#
# ```{bash}
# pip3 install bokeh
# pip3 install seaborn
# pip3 install pydataset
# ```
#
# Si vous rencontrez des erreurs pour l'installation d'un module, vous pouvez l'installer localement avec la commande suivante
#
# ```{bash}
# pip3 install --user package_name
# ```

# %% [markdown]
# Dans la suite, nous allons utiliser le jeu de données [`tips`](http://svitsrv25.epfl.ch/R-doc/library/reshape/html/tips.html), initialement présent dans le package `reshape2` de `R`. Pour le récupérer, on importe la fonction `data()` du module `pydataset`, et on l'obtient avec `data("tips")`. Pour avoir la liste des données présentes dans `pydataset`, vous pouvez taper la commande `data()` (ou aller voir [ici](https://github.com/iamaziz/PyDataset)).

# %%
from pydataset import data
tips = data('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Dans la suite, nous allons utiliser les modules `numpy` et `pandas` pour réaliser quelques manipulations.

# %%
import numpy
import pandas

# %% [markdown]
# ## `bokeh`
#
# Nous devons importer les modules dans le *notebook*. Voici tout d'abord les instructions pour `bokeh`. Pour ce module, ici, nous importons chaque fonction séparemment. Voici à quoi elles servent globalement :
#
# - `output_notebook()` : initialise le *notebook* pour la visualisation des graphiques produits
# - `show()` : montre le graphique
# - `color()` : permet de spécifier la palette ou les couleurs
# - `bins()` : découpe une variable quantitative en différents intervalles
# - `layouts()` : permet de mettre plusieurs graphiques sur la même figure
# - les autres : réalisent les différents graphiques
#
# Il existe en plus des fonctions permettant de réaliser un graphique *à la main*, en accédant à des primitives de dessins, laissant libre cours à votre imagination en terme de **Dataviz**.

# %%
from bokeh.plotting import output_notebook, show
from bokeh.charts import color, Histogram, BoxPlot, Bar, Donut, Scatter, HeatMap, bins
from bokeh import layouts
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c58e9415-b5e8-4a11-884b-6b7763398989">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Variable quantitative
#
# Dans aucun de ces deux modules, le *QQ plot* n'est implémenté directement, il faudra utiliser `scipy` pour le faire (non présenté ici).
#
# C'est la fonction `Histogram()` qui nous permet de réaliser un histogramme donc, en effectif par défaut.

# %%
h = Histogram(tips.total_bill)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bb3e494a-6d57-4992-ad55-da806ba66c12"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bb3e494a-6d57-4992-ad55-da806ba66c12").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bb3e494a-6d57-4992-ad55-da806ba66c12");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bb3e494a-6d57-4992-ad55-da806ba66c12' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"693e1ec3-8bc1-4597-80c2-9b530cb1b297":{"roots":{"references":[{"attributes":{"data_source":{"id":"c69111c9-209e-4f6c-9ca0-8a490ebd6ec4","type":"ColumnDataSource"},"glyph":{"id":"99b16b2c-ebc8-4d68-89be-fb87562a0f3d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ddc456d0-9ce2-46e3-b79e-41262772226c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(6.480000, 9.890000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14.0],"label":["(6.480000, 9.890000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.41],"x":["8.185"],"y":[7.0]}},"id":"f4440869-b1be-4349-b3bf-ea20bf4ba3e6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(40.580000, 43.990000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["
b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"85b4125e-53ed-4665-be63-ca63061c4459","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"33ae4105-6ff4-4a8b-ae0c-f64af2f857b8","subtype":"Chart","type":"Plot"}},"id":"f2d031e6-c8a8-4cbf-8da4-ea6b717e3b18","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(23.530000, 26.940000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.025239171193692612],"label":["(23.530000, 26.940000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.41],"x":["25.235"],"y":[0.012619585596846306]}},"id":"a860aa01-c7d5-47e5-8ed0-57d600b63bb2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ddcded91-28aa-429e-bad7-8711092bdf2f","type":"Rect"},{"attributes":{"overlay":{"id":"a6d0de45-1709-4e82-9b53-ef9214453663","type":"BoxAnnotation"},"plot":{"id":"33ae4105-6ff4-4a8b-ae0c-f64af2f857b8","subtype":"Chart","type":"Plot"}},"id":"5e9faa22-9c5b-4d40-b8df-8e158a511d37","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(26.940000, 30.350000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.01802797942406615],"label":["(26.940000, 30.350000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.41],"x":["28.645000000000003"],"y":[0.00901398 ...

# %% [markdown]
# Pour la boîte à moustaches, la fonction `BoxPlot()` est initialement prévu pour le croisement entre une variable qualitative (en $x$) et une variable quantitative (en $y$). Pour l'avoir en univarié, il nous faut donc créer une variable constante (nommée `const` ici, égale à `1`).

# %%
tips = tips.assign(const = 1)
p = BoxPlot(tips, values = "total_bill", label = "const")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0b631fc0-479e-4636-a3d1-9e0fdcbd80ee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0b631fc0-479e-4636-a3d1-9e0fdcbd80ee").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0b631fc0-479e-4636-a3d1-9e0fdcbd80ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0b631fc0-479e-4636-a3d1-9e0fdcbd80ee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d12bc9f-b3c2-4f8a-bd6f-b52673630ff0":{"roots":{"references":[{"attributes":{"data_source":{"id":"8a031740-d3cf-4f09-8093-429ae655ddd1","type":"ColumnDataSource"},"glyph":{"id":"d9b42610-65ee-4d49-977a-29e27518f9e4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"23ca208d-3031-466f-aac5-a6e784a1d205","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8318e678-6105-4447-9c50-7a93692ede93","subtype":"Chart","type":"Plot"}},"id":"67832b72-677c-47ce-b6af-939770985f61","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f97509a-8526-4017-ae94-19f56a35fdc3","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"const":1}],"color":["DimGrey"],"const":[1],"fill_alpha":[0.8],"height":[6.332499999999996],"label":[{"const":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[20.96125]}},"id":"8b443bc1-12a0-4b44-bea7-7a12aa8c22ac","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5117db93-3d20-480c-9acb-073dec136fbf","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":53.504000000000005},"id":"b7a3d57a-b334-44fc-b934-79b56467fea9","type":"Range1d"},{"attributes":{"data_source":{"id":"8b443bc1-12a0-4b44-bea7-7a12aa8c22ac","type":"ColumnDataSource"},"glyph":{"id":"4f97509a-8526-4017-ae94-19f56a35fdc3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31e44c36-cc6d-4394-afa6-9702268b9d02","type":"GlyphRenderer"},{"attributes":{},"id":"081b08df-c4d2-4320-89cb-b6e7a7d523cf","type":"BasicTickFormatter"},{"attributes":{},"id":"3fbe7768-bfb1-4f16-adab-9d99f1a06bc0","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"de0594c6-4ae4-4479-aa0f-dfac663f0185","type":"ColumnDataSource"},"glyph":{"id":"905810ab-f0b2-4704-b5ea-7b21005d09f6","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"77525b3e-864d-448d-acc2-c0972d8d9abe","type":"GlyphRenderer"},{"attributes":{"label":{"value":"1"},"renderers":[{"id":"23ca208d-3031-466f-aac5-a6e784a1d205","type":"GlyphRenderer"},{"id":"31e44c36-cc6d-4394-afa6-9702268b9d02","type":"GlyphRenderer"},{"id":"660b7e3e-5a4a-42b5-967d-87e19a81b8b5","type":"GlyphRenderer"},{"id":"77525b3e-864d-448d-acc2-c0972d8d9abe","type":"GlyphRenderer"}]},"id":"b247a7d9-febc-4a79-9db4-1874fb246c9b","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"const":1}],"color":["DimGrey"],"const":[1],"fill_alpha":[0.8],"height":[4.447500000000002],"label":[{"const":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[15.571250000000001]}},"id":"8a031740-d3cf-4f09-8093-429ae655ddd1","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"905810ab-f0b2-4704-b5ea-7b21005d09f6","type":"Segment"},{"attributes":{},"id":"f0b72bb5-14a9-4f35-b67d-57b07f8b33f2","type":"CategoricalTickFormatter"},{"attributes":{},"id":"cb2ad112-820a-4ee9-8b23-a742456c356a","type":"BasicTicker"},{"attributes":{"items":[{"id":"b247a7d9-febc-4a79-9db4-1874fb246c9b","type":"LegendItem"}],"location":"top_left","plot":{"id":"8318e678-6105-4447-9c50-7a93692ede93","subtype":"Chart","type":"Plot"}},"id":"85b1973d-d216-4562-bfb4-5 ...

# %% [markdown]
# ### Variable qualitative
#
# Le diagramme en barres est réalisé avec la fonction `Bar()`. Il est possible de déterminer une couleur en fonction du sexe avec le paramètre `color`.

# %%
p = Bar(tips, label = "sex", color = "sex")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="35b4ff0b-36fb-470e-86d5-23cd27073725"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("35b4ff0b-36fb-470e-86d5-23cd27073725").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("35b4ff0b-36fb-470e-86d5-23cd27073725");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '35b4ff0b-36fb-470e-86d5-23cd27073725' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"08cb7a53-027a-4fc9-b854-cd59dd429185":{"roots":{"references":[{"attributes":{"data_source":{"id":"d16c6769-9b57-47df-a069-086daa58cc95","type":"ColumnDataSource"},"glyph":{"id":"b29e5c86-ede5-41b6-9f16-f754fa4d3bda","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"456e1565-0f01-4f67-a83a-49c01a384aee","type":"GlyphRenderer"},{"attributes":{},"id":"f1e3d681-7d89-43ec-ac00-1bdfb395d999","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"8725bcad-18ba-46fd-a9ae-d0fed246c7e2","type":"ColumnDataSource"},"glyph":{"id":"50ba7526-582c-4ac7-bcc5-05d571cbf9eb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"96a31c4c-d0cf-4a32-8ade-af1a8eb5304c","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Female"},"renderers":[{"id":"96a31c4c-d0cf-4a32-8ade-af1a8eb5304c","type":"GlyphRenderer"}]},"id":"8da08b15-3636-4089-959e-4a01c9a680ce","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b29e5c86-ede5-41b6-9f16-f754fa4d3bda","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Male"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[157.0],"label":[{"sex":"Male"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Male"],"width":[0.8],"x":["Male"],"y":[78.5]}},"id":"d16c6769-9b57-47df-a069-086daa58cc95","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"be0436ab-2249-4723-9420-d59d056d52e9","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"21c1a4c2-8003-4871-81d7-6c86af444263","type":"LinearAxis"}],"renderers":[{"id":"30b5a31d-16a2-44e4-969d-9834ef56d784","type":"BoxAnnotation"},{"id":"96a31c4c-d0cf-4a32-8ade-af1a8eb5304c","type":"GlyphRenderer"},{"id":"456e1565-0f01-4f67-a83a-49c01a384aee","type":"GlyphRenderer"},{"id":"5368c6c3-0bca-4140-abc7-3f1588c9168e","type":"Legend"},{"id":"be0436ab-2249-4723-9420-d59d056d52e9","type":"CategoricalAxis"},{"id":"21c1a4c2-8003-4871-81d7-6c86af444263","type":"LinearAxis"},{"id":"bce9e3c1-b643-483c-9be7-c9b8683b2931","type":"Grid"}],"title":{"id":"4cac8b57-7a82-426b-b101-0d314544aa8b","type":"Title"},"tool_events":{"id":"b1200b7e-87cc-4bb2-93a8-bac8890c497e","type":"ToolEvents"},"toolbar":{"id":"394a5ada-e728-47e8-9dde-6a38f69f03ed","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"f9fe2e8c-e511-4c0a-a4d9-22437d9f0c09","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"908a2ac5-4e23-4b39-9ce1-ddf819c0daad","type":"Range1d"}},"id":"71708113-0d72-42da-a662-2e6fc8d232d3","subtype":"Chart","type":"Plot"},{"attributes":{"axis_label":"Count( Sex )","formatter":{"id":"abfce381-4d66-4623-be8b-168b7db4e9b0","type":"BasicTickFormatter"},"plot":{"id":"71708113-0d72-42da-a662-2e6fc8d232d3","subtype":"Chart","type":"Plot"},"ticker":{"id":"25c87d4b-5ed8-47cd-96cc-b02683a8fa1f","type":"BasicTicker"}},"id":"21c1a4c2-8003-4871-81d7-6c86af444263","type":"LinearAxis"},{"attributes":{"label":{"value":"Male"},"renderers":[{"id":"456e1565-0f01-4f67-a83a-49c01a384aee","type":"GlyphRenderer"}]},"id":"ebf75492-4525-41ce-a10c-f1f53d98167d","type":"LegendItem"},{"attributes":{},"id":"abfce381-4d66-4623-be8b-168b7db4e9b0","type":"BasicTickFormatter"},{"attributes":{},"id":"b1200b7e-87cc-4bb2-93a8-bac8890c497e","type":"ToolEvents"},{"attributes":{"axis_label":"Sex","formatter":{"id":"f1e3d681-7d89-43ec-ac00-1bdfb395d999","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"71708113-0d72-42da-a662-2e6fc8d232d3","subtype":"Chart","type":"Plot"},"ticker":{"id":"6e54dfdf-45c7-446f-99cb-5893bf1b3d9f","type":"CategoricalTicker"}},"id":"be0436ab-2249-4723-9420-d59d056d52e9","type":"CategoricalAxis"},{"a ...

# %% [markdown]
# Il est possible d'avoir le diagramme en barres empilées en représentant une constante en $x$, et en indiquant que l'empilage se fait sur la variable `sex` (avec le paramètre `stack`).

# %%
p = Bar(tips, "const", stack = "sex")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f1ba1ec2-92f9-4dfc-8361-1b542f67413d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f1ba1ec2-92f9-4dfc-8361-1b542f67413d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1ba1ec2-92f9-4dfc-8361-1b542f67413d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1ba1ec2-92f9-4dfc-8361-1b542f67413d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"816e48a4-8cac-4ae3-9a77-c2b8abf18858":{"roots":{"references":[{"attributes":{"overlay":{"id":"16073695-58f8-4221-be5d-5499e50992e3","type":"BoxAnnotation"},"plot":{"id":"c037ca96-7ff5-41c5-acd8-5d6b167a73b0","subtype":"Chart","type":"Plot"}},"id":"a1871f65-8254-4c53-8978-5fb713f1245a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c037ca96-7ff5-41c5-acd8-5d6b167a73b0","subtype":"Chart","type":"Plot"}},"id":"c2d91939-4847-4128-adfb-697145ca080b","type":"WheelZoomTool"},{"attributes":{"callback":null,"factors":["1"]},"id":"78e7e95e-9baa-4cc5-9b9f-5f44318ab29e","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"41063b5b-90c3-4541-99c9-8bb2f28efe97","type":"Rect"},{"attributes":{"label":{"value":"Female"},"renderers":[{"id":"871c12ab-e153-4579-a681-651bcaa80c82","type":"GlyphRenderer"}]},"id":"c5e5ab27-7cf8-4be6-bdc0-ae1e4d32d173","type":"LegendItem"},{"attributes":{},"id":"86d78e22-60f7-443b-a784-77ae4bd8646d","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"const":1,"sex":"Male"}],"color":["#5ab738"],"const":[1],"fill_alpha":[0.8],"height":[157.0],"label":[{"const":1,"sex":"Male"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Male"],"width":[0.8],"x":["1"],"y":[165.5]}},"id":"dbe6c2f2-f905-4d60-9498-b7f86f9fa758","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"c037ca96-7ff5-41c5-acd8-5d6b167a73b0","subtype":"Chart","type":"Plot"},"ticker":{"id":"300bfe42-5c21-408d-b1ea-c467966cd24e","type":"BasicTicker"}},"id":"bd051095-f7db-4caa-b12e-8e945f434e4b","type":"Grid"},{"attributes":{"axis_label":"Const","formatter":{"id":"db4144f2-0290-41e3-aef4-9e28bbf0e9ce","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"c037ca96-7ff5-41c5-acd8-5d6b167a73b0","subtype":"Chart","type":"Plot"},"ticker":{"id":"86d78e22-60f7-443b-a784-77ae4bd8646d","type":"CategoricalTicker"}},"id":"073a039e-07e3-4698-8947-cc98a709fda3","type":"CategoricalAxis"},{"attributes":{"below":[{"id":"073a039e-07e3-4698-8947-cc98a709fda3","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"e9f22333-e920-47b8-8003-7166de5e3e16","type":"LinearAxis"}],"renderers":[{"id":"16073695-58f8-4221-be5d-5499e50992e3","type":"BoxAnnotation"},{"id":"871c12ab-e153-4579-a681-651bcaa80c82","type":"GlyphRenderer"},{"id":"6f8ec3de-d015-4dc7-90b3-1011624a845b","type":"GlyphRenderer"},{"id":"ee9542b4-72b4-4116-b44a-06f7167de22c","type":"Legend"},{"id":"073a039e-07e3-4698-8947-cc98a709fda3","type":"CategoricalAxis"},{"id":"e9f22333-e920-47b8-8003-7166de5e3e16","type":"LinearAxis"},{"id":"bd051095-f7db-4caa-b12e-8e945f434e4b","type":"Grid"}],"title":{"id":"d2f54628-db6e-4ef1-9bbe-bca68b15bdf7","type":"Title"},"tool_events":{"id":"cdc56cbf-87aa-48e7-944f-007f744722a7","type":"ToolEvents"},"toolbar":{"id":"ff810ced-7467-447f-95da-86627e43851f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"78e7e95e-9baa-4cc5-9b9f-5f44318ab29e","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"70fbbd21-adba-4dc6-9154-25349ca20b8f","type":"Range1d"}},"id":"c037ca96-7ff5-41c5-acd8-5d6b167a73b0","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"dbe6c2f2-f905-4d60-9498-b7f86f9fa758","type":"ColumnDataSource"},"glyph":{"id":"41063b5b-90c3-4541-99c9-8bb2f28efe97","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6f8ec3de-d015-4dc7-90b3-1011624a845b","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line ...

# %% [markdown]
# Pour avoir ce diagramme sommé à 100, il est nécessaire de calculer tout d'abord les fréquences de chaque modalité dans un tableau. Puis de réprésenter ce tableau, en indiquant que les valeurs sont les pourcentages (via le paramètre `values`).

# %%
t = pandas.crosstab(tips.sex, "freq", normalize = True)
t = t.assign(sex = t.index, const = 1, percent = 100 * t.freq)
t
# Out:
# col_0       freq  const    percent     sex
# sex
# Female  0.356557      1  35.655738  Female
# Male    0.643443      1  64.344262    Male

# %%
p = Bar(t, label = "const", values = "percent", stack = "sex")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9d852a55-25f1-4bfd-8b9c-3cbab8091940","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","values"],"data":{"Count":["(15, 18.5]"],"chart_index":[{"Count":"(15, 18.5]"}],"values":[17],"x":{"__ndarray__":"AAAAAAAALkA=","dtype":"float64","shape":[1]},"y":{"__ndarray__":"AAAAAAAA/D8=","dtype":"float64","shape":[1]}}},"id":"e00d84cf-78d4-42c8-963a-60f4a75e38eb","type":"ColumnDataSource"},{"attributes":{"axis_label":"total_bill_center","formatter":{"id":"60c30b74-42e2-43b4-a394-6665ed3028aa","type":"BasicTickFormatter"},"plot":{"id":"a0b93be5-fc43-4d2a-9412-fde190d90bb7","subtype":"Chart","type":"Plot"},"ticker":{"id":"e16de09a-6728-4986-8c74-63acd755e787","type":"BasicTicker"}},"id":"5f76cc28-b79c-4b8a-8e60-36063a404970","type":"LinearAxis"},{"attributes":{},"id":"e16de09a-6728-4986-8c74-63acd755e787","type":"BasicTicker"},{"attributes":{"label":{"value":"(11.5, 15]"},"renderers":[{"id":"ab86779c-595d-4edd-9f6f-a61893a3e954","type":"GlyphRenderer"}]},"id":"698c26f0-39fe-4953-9f12-a3dcf7b0084a","type":"LegendItem"},{"attributes":{"dilate":true,"fill_color":{"value":"#eff3ff"},"height":{"units":"data","value":0.475},"line_color":{"value":"#eff3ff"},"width":{"units":"data","value":3.23},"x":{"field":"x"},"y":{"field":"y"}},"id":"98e852f0-7a89-4733-a4a3-8d18a457480a","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","values"],"data":{"Count":["(4.5, 8]","(4.5, 8]","(4.5, 8]","(4.5, 8]","(4.5, 8]","(4.5, 8]","(4.5, 8]","(4.5, 8]"],"chart_index":[{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"},{"Count":"(4.5, 8]"}],"values":[8,5,7,7,8,7,8,6],"x":{"__ndarray__":"zczMzMzMNUAzMzMzMzM5QAAAAAAAAC5AzczMzMzMNUBmZmZmZmYgQAAAAAAAAC5ANDMzMzMzJ0BmZmZmZmYyQA==","dtype":"float64","shape":[8]},"y":{"__ndarray__":"AAAAAAAACkAAAAAAAAAKQAAAAAAAAApAAAAAAAAABkAAAAAAAAD0PwAAAAAAAAZAAAAAAAAAAkAAAAAAAAAOQA==","dtype":"float64","shape":[8]}}},"id":"9cdd54b4-b36f-4f4a-83be-8c88cf222690","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"086482a4-a264-451b-be9e-6a0131e8bbee","type":"LegendItem"},{"id":"ea1e24fc-58e8-4846-8ba6-e90c1e94664d","type":"LegendItem"},{"id":"698c26f0-39fe-4953-9f12-a3dcf7b0084a","type":"LegendItem"},{"id":"9f9ebfa3-fa82-4229-a1e6-1cf63998cf5f","type":"LegendItem"},{"id":"9a523833-220b-4605-b15a-14fa840b7e6a","type":"LegendItem"},{"id":"81ec9efc-c2a5-4de4-a418-468ffc9132d8","type":"LegendItem"} ...

# %% [markdown]
# Dans cette fonction `bins()`, comme pour un histogramme, il est possible de choisir son découpage avec le paramètre `bins` (soit via le nombre de *bins*, soit en donnant les limites des intervalles).

# %%
p = HeatMap(tips, bins("total_bill", bins = 5), bins("tip", bins = 7))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a7bffa82-f531-4c0e-9900-9501832477c3","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"Yes"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[33.0],"label":[{"sex":"Female","smoker":"Yes"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["Yes"],"width":[0.2],"x":["Female:0.666666666667"],"y":[16.5]}},"id":"bb42f295-fd6f-4bbd-b4da-ef24cfa56ace","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"59843713-2440-430b-a841-fe889dc69634","subtype":"Chart","type":"Plot"}},"id":"3c2f6966-00e0-46f0-b5c4-fa7df3f59539","type":"ResetTool"},{"attributes":{},"id":"639ccf19-b3aa-40a8-8ba8-016476ebfbd9","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"7a8091fb-ba6b-4b5e-ada2-dba2a732a659","type":"Title"},{"attributes":{},"id":"57bb84d2-7965-4f98-a39e-deba0de26b65","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[54.0],"label":[{"sex":"Female","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["No"],"width":[0.2],"x":["Female:0.333333333333"],"y":[27.0]}},"id":"a6df817c-2131-43b6-a420-2eb66e503eef","type":"ColumnDataSource"},{"attributes":{},"id":"aa26cc7a-7be1-42a7-be40-52402a20f1e1","type":"BasicTicker"},{"attributes":{"plot":{"id":"59843713-2440-430b-a841-fe889dc69634","subtype":"Chart","type":"Plot"}},"id":"b673261a-775f-4a7a-9237-475e08c63c8a","type":"HelpTool"},{"attributes":{},"id":"e3fc87d4-0f93-48cc-a849-9eaff97f2db4","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"Sex","formatter":{"id":"e3fc87d4-0f93-48cc-a849-9eaff97f2db4","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"59843713-2 ...

# %% [markdown]
# Pour avoir ce diagramme en pourcentages (ou proportions), il faut tout d'abord calculer les profils sur la variable `sex`.

# %%
t = pandas.crosstab(tips.sex, tips.smoker, normalize = "index")
t = t.assign(sex = t.index)
t
# Out:
# smoker        No       Yes     sex
# sex
# Female  0.620690  0.379310  Female
# Male    0.617834  0.382166    Male

# %% [markdown]
# Ensuite, nous utilisons la fonction `melt()` de `pandas` permettant de modifier la structure d'un tableau.

# %%
tm = pandas.melt(t, id_vars=["sex"])
tm.value = 100 * tm.value
tm
# Out:
#       sex smoker      value
# 0  Female     No  62.068966
# 1    Male     No  61.783439
# 2  Female    Yes  37.931034
# 3    Male    Yes  38.216561

# %% [markdown]
# Enfin, à partir de cette table, il est facile de réaliser le diagramme en barres en pourcentages.

# %%
p = Bar(tm, label = "sex", values = "value", group = "smoker")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6099de6-b1fa-418d-a5c7-c110424b5783"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e6099de6-b1fa-418d-a5c7-c110424b5783").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6099de6-b1fa-418d-a5c7-c110424b5783");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6099de6-b1fa-418d-a5c7-c110424b5783' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"517fef79-0291-4b5c-8e51-61cf534fe1ff":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f598791c-0829-4105-97fd-8b2a2474eb49","type":"Rect"},{"attributes":{},"id":"2b17c326-95fa-4d37-86a6-fa052b0bc36d","type":"CategoricalTickFormatter"},{"attributes":{},"id":"deaf43fd-e2c4-41e4-b53c-ea290c81dbd1","type":"CategoricalTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":
type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ba02165-4085-48c8-9796-a980c6895288","type":"Rect"},{"attributes":{"data_source":{"id":"2acda4f7-fb7e-4417-86a7-5a038ab13af0","type":"ColumnDataSource"},"glyph":{"id":"8ba02165-4085-48c8-9796-a980c6895288","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"be97ba21-6f88-40d1-aeaa-be21eb385fbf","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c704340e-c5c4-41ea-9d91-db49613d7e27","type":"Rect"},{"attributes":{"axis_label":"Sex","formatter":{"id":"f5487015-07ea-4e51-91f4-1642b3096b65","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"0b35eac6-076f-4076-aa6a-b3b01c4669f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"2c9d4fd1-2637-4b4b-b4e0-04fe83e86cb1","type":"CategoricalTicker"}},"id":"28dc2688-9062-4de3-b113-12ef16e6e050","type":"CategoricalAxis"},{"attributes":{"label":{"value":"No"},"renderers":[{"id":"2c201170-1cd9-4aff-9827-f5b260096e1d","type":"GlyphRenderer"}]},"id":"9b534dee-3b3c-4171-938a-29edd67f21e4","type":"LegendItem"},{"attributes":{},"id":"f5487015-07ea-4e51-91f4-1642b3096b65","type":"CategoricalTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"0b35eac6-076f-4076-aa6a-b3b01c4669f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"5fc7fb8c-0644-4b62-9191-f9e0755a1644","type":"BasicTicker"}},"id":"fa05197d-d67c-409d-9414-122e631d52a4","type":"Grid"},{"attributes":{},"id":"74356fe7-264d-46df-bb75-463e0f66516f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"c9357b73-d91e-431f-b89a-ff1defe169dd","type":"ColumnDataSource"},"glyph":{"id":"5de0be38-4894-4757-bbe7-2ba2c8a97b3b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"92b8ec7d-1e1f-4db8-aade-f1e67a8078fe","type":"GlyphRenderer"},{"attributes":{},"id":"d6dd9f0c-9fcb-4d4f-999b-13b0dbc954b2","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aaf8e6bb-9247-4f45-9561-ef2dc03af729","type":"PanTool"},{"id":"2f327b1c-92e3-4a11-87ec-102dac3789ea","type":"WheelZoomTool"},{"id":"71beac0b-5dc4-45f7-b919-424c82a768e4","type":"BoxZoomTool"},{"id":"7efd053e-ddf5-47f2-a663-ffe5bba7420e","type":"SaveTool"},{"id":"9d727355-a7be-4abd-af11-0cd9fe3a1f63","type":"ResetTool"},{"id":"c65e2b0a-86a0-43df-85fe-11676520081e","type":"HelpTool"}]},"id":"90d6d1d0-c4b1-4371-bde9-b46acf69f55a","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[62.06896551724138],"label":[{"sex":"Female","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["No"],"width":[0.8],"x":["Female"],"y":[31.03448275862069]}},"id":"8e360292-8102-4d2e-a239-363c3f736678","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":null},"id":"742e8b33-1e3e-4311-a0c3-4ff5f519366d","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen", ...

# %% [markdown]
# Pour avoir un diagramme circulaire d'une variable par modalité d'une autre variable, il est nécessaire de créer plusieurs graphiques et de les mettre ensemble, avec la fonction `layouts.row()` (en lignes - et `.column()` en colonnes).

# %%
pSmokerYes = Donut(tips.query('smoker == "Yes"'), "sex", title = "Yes")
pSmokerNo  = Donut(tips.query('smoker == "No"'), "sex", title = "No")
p = layouts.row(pSmokerYes, pSmokerNo)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="91b9f817-65bb-47cb-8376-1587372c2ec1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("91b9f817-65bb-47cb-8376-1587372c2ec1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("91b9f817-65bb-47cb-8376-1587372c2ec1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '91b9f817-65bb-47cb-8376-1587372c2ec1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"42e76095-82e4-487f-b7ca-4d89dbfce705":{"roots":{"references":[{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"6f5a0179-08ec-441f-831b-ec9d02ab6fa9","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"636f27e3-feb2-480a-b218-8a234fb4b6e4","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"81638e48-7006-4493-a626-4b23d941b985","type":"ColumnDataSource"},"glyph":{"id":"cea9302b-6e5f-4d81-b939-e36118ba4ddb","type":"AnnularWedge"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2edf8d0f-ffe3-49d1-9aac-ed6c6b58206d","type":"GlyphRenderer"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"cea9302b-6e5f-4d81-b939-e36118ba4ddb","type":"AnnularWedge"},{"attributes":{"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"cc97f7bc-0ddd-4d3c-a720-846f1084f5ce","type":"PanTool"},{"attributes":{"overlay":{"id":"20d7f50b-867c-4775-8d66-5218bd1c1bf3","type":"BoxAnnotation"},"plot":{"id":"6b5ccc64-6f73-4d90-8748-fd14314ac816","subtype":"Chart","type":"Plot"}},"id":"5a67a7b1-d1e6-4d11-a904-8a65efadde5c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"1a6bd295-79a2-4f15-8d27-fd009170a5f0","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"636f27e3-feb2-480a-b218-8a234fb4b6e4","type":"BoxAnnotation"},"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"ada54858-a4b9-4f4e-ad4e-5cb9a81ea7c9","type":"BoxZoomTool"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"37c47016-5cd8-4167-942d-8aa2139b18b8","type":"Text"},{"attributes":{"plot":{"id":"6b5ccc64-6f73-4d90-8748-fd14314ac816","subtype":"Chart","type":"Plot"}},"id":"275b92c2-4e98-4180-9ada-4a20433247dd","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"90a071de-66b5-44c1-848b-b074ccd1f7d9","type":"SaveTool"},{"attributes":{"plot":{"id":"6b5ccc64-6f73-4d90-8748-fd14314ac816","subtype":"Chart","type":"Plot"}},"id":"ffd3f0f5-ca6f-4603-b658-f0d5995421dc","type":"SaveTool"},{"attributes":{"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"d7ef7666-e9f9-4f90-9dad-2fd5b20d2a53","type":"ResetTool"},{"attributes":{"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"9091f9f5-eeec-46c7-8c79-53c445095ecd","type":"HelpTool"},{"attributes":{"plot":{"id":"6b5ccc64-6f73-4d90-8748-fd14314ac816","subtype":"Chart","type":"Plot"}},"id":"cfacddc7-9b83-4bf7-a218-09ae1350442d","type":"ResetTool"},{"attributes":{},"id":"af671fac-697d-47f4-bfbf-7369b8061838","type":"BasicTicker"},{"attributes":{"axis_label":null,"formatter":{"id":"3c7a81ca-b5c0-4b2a-a21a-a8869940eeeb","type":"BasicTickFormatter"},"plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"},"ticker":{"id":"af671fac-697d-47f4-bfbf-7369b8061838","type":"BasicTicker"},"visible":false},"id":"48cd4ba6-ddfb-4d63-8364-0b97dddecc56","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"11a71544-0672-401b-9864-11604450e88a","subtype":"Chart","type":"Plot"}},"id":"1fbbaeb3-9ada-472e-9172-b2a5987ba143","type" ...

# %% [markdown]
# Avec une *list comprehension* et l'utilisation de liste de paramètre (avec `*`), il est possible de réaliser cela en une seule étape.

# %%
p = layouts.row(*[Donut(tips.query('smoker == "' + m + '"'), "sex", title = 'smoker: ' + m) 
                  for m in tips.smoker.unique()])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"951d6296-4986-41d7-80a2-9e8f47d2c0e5","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"59893ae5-e87a-439e-a4d5-7a5b374964ee","type":"Range1d"}},"id":"5f48542b-571c-4e20-9b98-daaf920e6e4c","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"bbaf50ed-1b72-4634-bfb3-4270507efb3d","type":"Range1d"},{"attributes":{"axis_label":null,"formatter":{"id":"cd455bf4-9226-447c-b482-de698348baab","type":"BasicTickFormatter"},"plot":{"id":"5f48542b-571c-4e20-9b98-daaf920e6e4c","subtype":"Chart","type":"Plot"},"ticker":{"id":"b045e01d-27e4-4d08-9796-b360c2b86027","type":"BasicTicker"},"visible":false},"id":"3a3cc145-a2b5-4e21-85cb-4adbabf54167","type":"LinearAxis"},{"attributes":{"plot":null,"text":"smoker: Yes"},"id":"a9ac9e9a-c088-46a6-88b0-d7ce519b520a","type":"Title"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"951d6296-4986-41d7-80a2-9e8f47d2c0e5","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"75f6bc7d-dcc2-40cb-ad06-3267577e7ca7","type":"PanTool"},{"id":"67fa9df5-9ecc-4a61-8a2b-6990e02d293b","type":"WheelZoomTool"},{"id":"12bb34c1-ba92-44c0-b8a0-21a7af69e876","type":"BoxZoomTool"},{"id":"672e3335-557b-4a11-8fc8-25246ceae6a1","type":"SaveTool"},{"id":"a89bf060-8f95-4081-b2 ...

# %% [markdown]
# ### Var quantitative - Var qualitative
#
# La représentation la plus simple à obtenir est les boîtes à moustaches pour chaque modalité, grâce à la fonction `BoxPlot()`.

# %%
p = BoxPlot(tips, values = "total_bill", label = "sex", color = "sex")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5358a97c-2712-40b0-a460-d8c51b7d70b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5358a97c-2712-40b0-a460-d8c51b7d70b0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5358a97c-2712-40b0-a460-d8c51b7d70b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5358a97c-2712-40b0-a460-d8c51b7d70b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f6ae443e-1477-4a07-b704-0cf9b3efbdc1":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c5c05600-e61b-483d-b7ee-5e31c54b5dda","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"}},"id":"2a664f45-9dc4-43a0-9414-28a26de7131b","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"c5c05600-e61b-483d-b7ee-5e31c54b5dda","type":"BoxAnnotation"},"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"}},"id":"83e8b59d-66ef-4b4f-97ed-d871dea90efa","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"}},"id":"9f47db1f-8306-4875-af89-5d32034ea407","type":"SaveTool"},{"attributes":{"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"}},"id":"fdcf545c-c759-4a8a-85a3-2a8b004f5b27","type":"ResetTool"},{"attributes":{"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"}},"id":"acc0046a-6c39-40a0-b760-f71b1f00e095","type":"HelpTool"},{"attributes":{"data_source":{"id":"89652655-842d-4c1c-b757-442ca2aed3b9","type":"ColumnDataSource"},"glyph":{"id":"8a6def18-8672-4a90-bc8b-394138a93bee","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dcd1c409-fdd6-4f2d-8128-63bd66f9f3d7","type":"GlyphRenderer"},{"attributes":{},"id":"e281b44b-4b2a-42ae-bf2d-5e329f09dcf7","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"3d3bac40-57a8-4a37-879f-936d9080776e","subtype":"Chart","type":"Plot"},"ticker":{"id":"e281b44b-4b2a-42ae-bf2d-5e329f09dcf7","type":"BasicTicker"}},"id":"4c896b6b-b686-42a3-913a-19f7c87afb3e","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Male"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[6.359999999999999],"label":[{"sex":"Male"}],"line_alpha":[1.0],"line_color":["black"],"sex":["Male"],"width":[0.8],"x":["Male"],"y":[21.53]}},"id":"89652655-842d-4c1c-b757-442ca2aed3b9","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f73ef1dc-49ba-4397-aa70-ded3e483fdcd","type":"PanTool"},{"id":"2a664f45-9dc4-43a0-9414-28a26de7131b","type":"WheelZoomTool"},{"id":"83e8b59d-66ef-4b4f-97ed-d871dea90efa","type":"BoxZoomTool"},{"id":"9f47db1f-8306-4875-af89-5d32034ea407","type":"SaveTool"},{"id":"fdcf545c-c759-4a8a-85a3-2a8b004f5b27","type":"ResetTool"},{"id":"acc0046a-6c39-40a0-b760-f71b1f00e095","type":"HelpTool"}]},"id":"15c0db6f-c7a1-495c-b9e4-14e865c3f040","type":"Toolbar"},{"attributes":{},"id":"2b472786-0800-4dbf-9f16-04afe19168d5","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"0ecdeb95-3bd0-4a14-9299-163b1774ca54","type":"ColumnDataSource"},"glyph":{"id":"bed186d8-fee7-4277-94ad-e954ac20db36","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ce07e1f9-7634-432c-bef4-61175cbba1e9","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"e7eb3e9d-89a6-46c5-a00d-a273471b124b","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"6a93cdb4-d060-46e9-a093-446fa73d2182","type":"LinearAxis"}],"renderers":[{"id":"c5c05600-e61b-483d-b7ee-5e31c54b5dda","type":"BoxAnnotation"},{"id":"ce07e1f9-7634-432c-bef4-61175cbba1e9","type":"GlyphRenderer"},{"id":"74619004-ac8b-4db6-9143-7596bd90d0ed","type":"GlyphRenderer"},{"id":"491b8959-7e40-4026-97d4-e18a67f3fd67","type":"GlyphRenderer"},{"id":"9e7552b6-4c5e-4bc6-ae07-4956649e9ca5","type":"GlyphRenderer"},{"id":"f377988c-b488-4382-89b0-845105872b57","type" ...

# %% [markdown]
# Ensuite, nous pouvons créer les histogrammes de `total_bill` pour chaque modalité de `sex`, avec un `layouts` en colonnes (`column()`).

# %%
p = layouts.column(*[Histogram(tips.query('sex == "' + m + '"'), 
                               "total_bill",
                               density = True,
                               title = 'sex: ' + m,
                               plot_height = 200,
                              ) 
                     for m in tips.sex.unique()])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a7060fca-26fb-4087-903f-b69400072765"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a7060fca-26fb-4087-903f-b69400072765").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a7060fca-26fb-4087-903f-b69400072765");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a7060fca-26fb-4087-903f-b69400072765' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d296805e-9dcf-477b-8503-29c6ca3462bc":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(46.850000, 50.810000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.006433764395547834],"label":["(46.850000, 50.810000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.960000000000001],"x":["48.83"],"y":[0.003216882197773917]}},"id":"97951c67-d397-4c96-981f-ea65acd68fca","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"97951c67-d397-4c96-981f-ea65acd68fca","type":"ColumnDataSource"},"glyph":{"id":"2aa1cf9e-204a-459c-b8ce-c93e2daad098","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"96535265-08fa-45b4-816e-0d91520874fd","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(40.551818, 44.300000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.006133241892272403],"label":["(40.551818, 44.300000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.7481818181818127],"x":["42.425909"],"y":[0.0030666209461362014]}},"id":"4f912253-4b2b-43b1-93a7-560418ccda9e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(15.170000, 19.130000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.05951232065881746],"label":["(15.170000, 19.130000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.960000000000001],"x":["17.15"],"y":[0.02975616032940873]}},"id":"0f86758a-ae6b-419d-add1-c268a05ccac9","type":"ColumnDataSource"},{"attributes":{"axis_label":"total_bill","formatter":{"id":"0ce821fb-3496-49c8-8be7-607ac9750963","type":"BasicTickFormatter"},"plot":{"id":"48c81a34-c000-4b9e-99eb-29db9b72df5e","subtype":"Chart","type":"Plot"},"ticker":{"id":"420defc7-89f6-4a1e-966e-c5fc5b59ad67","type":"BasicTicker"}},"id":"e84c92b3-ff13-4216-bc0f-2a2c005cd8f5","type":"LinearAxis"},{"attributes":{"data_source":{"id":"0f86758a-ae6b-419d-add1-c268a05ccac9","type":"ColumnDataSource"},"glyph":{"id":"dfd276c2-add8-4cce-aec3-6fe69fb88863","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ab3fc95-0107-4679-bb8a-c4399110265c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(36.803636, 40.551818]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(36.803636, 40.551818]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.74818181818182],"x":["38.677727"],"y":[0.0]}},"id":"135463aa-a44d-4b0b-8284-a9b3195afed2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"135463aa-a44d-4b0b-8284-a9b3195afed2","type":"ColumnDataSource"},"glyph":{"id":"38342f87-e83e-4571-aa79-558fae2ec064","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"30f4826a-5194-48d4-a9a9-9deb2a27be62","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(19.130000, 23.090000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.03860258637328701],"label":["(19.130000, 23.090000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.960000000000001],"x":["21.11"],"y":[0.019301293186643503]}},"id":"b852b046-08c3-4dab-b82a-5685d2b67e87","type":"ColumnDataSource"},{"attributes":{},"id":"0c62b358-f3ce-48c5-84bb-008f82c87c6e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"48c81a34-c000-4b9e-99eb-29db9b72df5e","subtype":"Chart","type":"Plot"},"ticker":{"id":"0c62b358-f3ce-48c5-84bb-008f82c87c6e","type":"BasicTicker"}},"id":"ee213d77-54d6-4854-8850-85d35910bbd2","type":"Gri ...

# %% [markdown]
# ### Multivariables

# %% [markdown]
# #### Trois quantitatives
#
# Dans ce cas, il est possible de réaliser une *heatmap*, dans laquelle chaque rectangle croisement de deux intervalles pour deux variables (ici `total_bill`et `size`) est coloré en fonction de la valeur moyenne d'une troisième variable (ici `tip`).

# %%
p = HeatMap(tips, x = bins("total_bill", bins = 5), y = "size", values = "tip",
           stat = "mean")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="44383a01-48b7-4091-b77c-ea4b93accffc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("44383a01-48b7-4091-b77c-ea4b93accffc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("44383a01-48b7-4091-b77c-ea4b93accffc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '44383a01-48b7-4091-b77c-ea4b93accffc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dcc4742c-ae08-4c0c-9e3f-0faa868cced2":{"roots":{"references":[{"attributes":{"data_source":{"id":"95c55d03-100e-4c29-85b2-c56bc9f769ce","type":"ColumnDataSource"},"glyph":{"id":"36f66555-25e2-4c22-9226-fd06aba887b4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"69dac598-9e23-410a-b213-165f6b998587","type":"GlyphRenderer"},{"attributes":{"callback":null,"end
","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"48d44cd7-0818-4924-b7e4-2577db9f5446","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2e248a68-ea1f-4092-8639-a64e9ae1190d","type":"PanTool"},{"id":"d96f3322-69c2-42f7-91d5-2eb41b377803","type":"WheelZoomTool"},{"id":"3c0b6006-93e1-4074-93f5-9c76eea695a2","type":"BoxZoomTool"},{"id":"9d804735-6e06-429a-b284-4e6dbde246bc","type":"SaveTool"},{"id":"83b11386-6eef-4c80-bc3b-9c5449b8ae27","type":"ResetTool"},{"id":"3336f42f-1901-4d8b-a919-f5b3ac59d790","type":"HelpTool"}]},"id":"751ecf93-04cb-456d-8f5a-5b0d9892820f","type":"Toolbar"},{"attributes":{"plot":{"id":"0ca51eee-75c1-4570-a9f3-c3ec6c556862","subtype":"Chart","type":"Plot"}},"id":"83b11386-6eef-4c80-bc3b-9c5449b8ae27","type":"ResetTool"},{"att ...

# %% [markdown]
# #### 2 quantitatives + 1 qualitative
#
# Ici, le plus simple est de réaliser un nuage de points, en colorant les points en fonction de la variable qualitative.

# %%
p = Scatter(tips, "total_bill", "tip", color = "sex")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b65fdd4-a371-4d2e-bf28-482aa6edef0e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5b65fdd4-a371-4d2e-bf28-482aa6edef0e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b65fdd4-a371-4d2e-bf28-482aa6edef0e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b65fdd4-a371-4d2e-bf28-482aa6edef0e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6012cf01-8ff8-4a04-ae1b-d57d20a4f618":{"roots":{"references":[{"attributes":{"items":[{"id":"f61a739e-e8a8-4cdc-9f7e-24fe25a9be7f","type":"LegendItem"},{"id":"1c9634a8-7e67-4600-8146-d83061853c17","type":"LegendItem"}],"location":"top_left","plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"}},"id":"a09c7f69-810c-4e44-82b2-14ebef02c81a","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2769ba46-fa7c-42fb-a451-7b0c0926157c","type":"BoxAnnotation"},{"attributes":{},"id":"e6dba9a5-4c34-4a77-ab66-aad2946c5b41","type":"BasicTicker"},{"attributes":{},"id":"c7ed92f6-3c18-477c-89ad-2f978392ed92","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Female"},"renderers":[{"id":"5c217d8b-9765-48a0-9447-927a1d9de822","type":"GlyphRenderer"}]},"id":"f61a739e-e8a8-4cdc-9f7e-24fe25a9be7f","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ba68b1e2-609b-45f4-b605-4a37c163a53f","type":"Circle"},{"attributes":{},"id":"bf3dafe3-c663-4f26-8e01-2904a63c2419","type":"ToolEvents"},{"attributes":{"data_source":{"id":"e130b29c-31e9-42f9-81f3-a9ef44f4fb66","type":"ColumnDataSource"},"glyph":{"id":"ba68b1e2-609b-45f4-b605-4a37c163a53f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5c217d8b-9765-48a0-9447-927a1d9de822","type":"GlyphRenderer"},{"attributes":{},"id":"2b0ce7b5-1d8f-4e79-8953-bb6c91575da4","type":"BasicTicker"},{"attributes":{"plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"}},"id":"f5a4cfae-4564-4f72-9c52-066461ae9b8b","type":"ResetTool"},{"attributes":{"plot":null,"text":null},"id":"ca7b9a00-26d2-4636-be3f-3f050b87b555","type":"Title"},{"attributes":{"axis_label":"total_bill","formatter":{"id":"c7ed92f6-3c18-477c-89ad-2f978392ed92","type":"BasicTickFormatter"},"plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"},"ticker":{"id":"e6dba9a5-4c34-4a77-ab66-aad2946c5b41","type":"BasicTicker"}},"id":"b9e2b5dc-5337-4eb5-bb84-a950c8bbca93","type":"LinearAxis"},{"attributes":{"plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"}},"id":"120d2ca4-3a5a-41a9-ac20-715a9dab18f9","type":"SaveTool"},{"attributes":{"axis_label":"tip","formatter":{"id":"a3bf111c-2630-43e5-9283-c32655706aa7","type":"BasicTickFormatter"},"plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"},"ticker":{"id":"2b0ce7b5-1d8f-4e79-8953-bb6c91575da4","type":"BasicTicker"}},"id":"69928e85-2c32-4c91-8df5-8fea0ea31739","type":"LinearAxis"},{"attributes":{"plot":{"id":"19df30e9-bf98-4f8e-9881-1b28b88f794c","subtype":"Chart","type":"Plot"}},"id":"ada274a4-bc51-4f92-9c5e-8dc97d5f41d4","type":"PanTool"},{"attributes":{"callback":null,"end":55.584,"start":-1.7040000000000002},"id":"1e6d3288-6e6e-4936-b666-cbff0109a9a7","type":"Range1d"},{"attributes":{},"id":"a3bf111c-2630-43e5-9283-c32655706aa7","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":10.9,"start":0.09999999999999998},"id":"4c13aab7-6d6c-4e8e-b05e-f0047f1b077a","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{ ...

# %% [markdown]
# #### 1 quantitative + 2 qualitatives
#
# En reprenant la fonction `BoxPlot()`, il est possible de créer un découpage sur plusieurs variables qualitatives en donnant une liste au paramètre `label`.

# %%
p = BoxPlot(tips, values = "total_bill", label = ["sex", "smoker"], color = ["sex", "smoker"])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fd27b542-9716-4418-a6d4-2c72b155d496"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fd27b542-9716-4418-a6d4-2c72b155d496").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fd27b542-9716-4418-a6d4-2c72b155d496");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fd27b542-9716-4418-a6d4-2c72b155d496' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4c8048c4-7151-4951-bcf3-9185bf3fe3ec":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6855a25f-44c5-48c4-afba-cd196a980b72","type":"Rect"},{"attributes":{"data_source":{"id":"92591c76-3b7b-4aed-a3bb-2f62d37dbddc","type":"ColumnDataSource"},"glyph":{"id":"5c3938a7-4a85-4a01-9a90-eab44d6887bd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"84487cf0-39f8-484d-b434-722d6f8a030a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8d21174b-5aae-4b00-b498-116a7af4ec46","type":"ColumnDataSource"},"glyph":{"id":"7e7d4cb2-d391-464f-972b-b109024a8e9e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3aa82f91-dafd-49c3-abc6-a75499d86f27","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"93e318d1-11ba-4d07-a419-27203b827133","subtype":"Chart","type":"Plot"}},"id":"dead80e7-eb33-4aaa-8343-89dba3d45c8d","type":"PanTool"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"15d16f92-1129-4430-b828-0025fe632600","type":"Segment"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"356f2ea0-57db-48e9-b419-056f907236f8","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"e17d43c6-14e0-44e6-b8f7-b21160d36bad","type":"Segment"},{"attributes":{"label":{"value":"('Male', 'Yes')"},"renderers":[{"id":"8c98965e-7d99-492c-8754-7281c029c80b","type":"GlyphRenderer"},{"id":"32a61f30-397b-4c74-bddc-4d09567ae913","type":"GlyphRenderer"},{"id":"3aa82f91-dafd-49c3-abc6-a75499d86f27","type":"GlyphRenderer"},{"id":"36298d6a-b7ac-4a0d-b26d-06dfb77058e3","type":"GlyphRenderer"}]},"id":"ce805ced-0ca3-4045-a4a5-a4b8cc102cfa","type":"LegendItem"},{"attributes":{"label":{"value":"('Female', 'No')"},"renderers":[{"id":"7a85dea7-7d00-4075-bd7e-4f8bb5cd62b9","type":"GlyphRenderer"},{"id":"8101938f-c665-4fcd-a9f3-e8c0382b6200","type":"GlyphRenderer"},{"id":"4f19f9e2-524d-41b3-8e2d-e751cb961909","type":"GlyphRenderer"},{"id":"0cf07c96-485f-472c-9278-5cb07768cfbd","type":"GlyphRenderer"}]},"id":"2361097c-58ab-4663-9cc2-6bfbf8049898","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"sex":"Female","smoker":"Yes"},{"sex":"Female","smoker":"Yes"},{"sex":"Female","smoker":"Yes"},{"sex":"Female","smoker":"Yes"}],"sex":["Female","Female","Female","Female"],"smoker":["Yes","Yes","Yes","Yes"],"x0s":["('Female', 'Yes'):0.5","('Female', 'Yes'):0.65","('Female', 'Yes'):0.5","('Female', 'Yes'):0.65"],"x1s":["('Female', 'Yes'):0.5","('Female', 'Yes'):0.35","('Female', 'Yes'):0.5","('Female', 'Yes'):0.35"],"y0s":[3.07,3.07,22.12,36.160000000000004],"y1s":[12.76,3.07,36.160000000000004,36.160000000000004]}},"id":"06539e44-b262-404a-b452-b27a3b21fdda","type":"ColumnDataSource"},{"attributes":{"label":{"value":"('Male', 'No')"},"renderers":[{"id":"84487cf0-39f8-484d-b434-722d6f8a030a","type":"GlyphRenderer"},{"id":"afedf6bd-9f6e-4612-90cc-7e1b25e61a02","type":"GlyphRenderer"},{"id":"cabe0f23-b0b8-4830-87c4-6584b3217833","type":"GlyphRenderer"},{"id":"499a31d3-1865-4c64-b1a2-018433b2e7a1","type":"GlyphRenderer"}]},"id":"c006943b-909e-4686-a499-dc72b6166ce4","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":nul ...

# %% [markdown]
# #### 3 qualitatives
#
# Pour ce cas, on peut réaliser le diagramme en barres empilées (ou séparées) entre deux variables, pour chaque modalité d'une troisième variable.

# %%
p = layouts.column(*[Bar(tips.query('time == "' + m + '"'), "sex", 
                         stack = "smoker", title = 'time: ' + m,
                         plot_height = 200) 
                     for m in tips.time.unique()])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6967783c-547d-4fd2-8457-e2edcdf93130"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6967783c-547d-4fd2-8457-e2edcdf93130").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6967783c-547d-4fd2-8457-e2edcdf93130");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6967783c-547d-4fd2-8457-e2edcdf93130' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01a2fb23-6fae-473f-897b-74529cd9dc7b":{"roots":{"references":[{"attributes":{"callback":null,"factors":["Female","Male"]},"id":"581d8114-2d90-4a40-b0e7-853af58913c7","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Male","smoker":"Yes"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[13.0],"label":[{"sex":"Male","smoker":"Yes"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Male"],"smoker":["Yes"],"width":[0.8],"x":["Male"],"y":[26.5]}},"id":"496b658e-3053-4a99-b2cb-fd32f68bcf66","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"da3ad744-5ecb-4b9a-a797-315ce65d5461","subtype":"Chart","type":"Plot"},{"id":"6a140a1a-fc59-4479-a726-95d1e21503db","subtype":"Chart","type":"Plot"}]},"id":"d38000e9-0ffc-4a73-b97f-0852af5dd9b1","type":"Column"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"Yes"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[10.0],"label":[{"sex":"Female","smoker":"Yes"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["Yes"],"width":[0.8],"x":["Female"],"y":[30.0]}},"id":"1566516b-cf2f-4961-ac4e-f92462439189","type":"ColumnDataSource"},{"attributes":{},"id":"6337470e-a29e-4031-b9a7-276caa7b6ef6","type":"BasicTickFormatter"},{"attributes":{},"id":"1fd50210-ef39-42e0-ba32-7d63b63bf2e0","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[29.0],"label":[{"sex":"Female","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["No"],"width":[0.8],"x":["Female"],"y":[14.5]}},"id":"cf6564ce-0a7d-45b7-8ae0-badc9b748155","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( Sex )","formatter":{"id":"6337470e-a29e-4031-b9a7-276caa7b6ef6","type":"BasicTickFormatter"},"plot":{"id":"6a140a1a-fc59-4479-a726-95d1e21503db","subtype":"Chart","type":"Plot"},"ticker":{"id":"96b2447b-7ed3-4c46-ac45-fca0e82c3d16","type":"BasicTicker"}},"id":"65a78283-852e-4bf7-953a-bb893171e665","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d7553ebd-dd62-4c08-ba45-3d843e0394e8","type":"Rect"},{"attributes":{"data_source":{"id":"22b84126-06eb-40bf-be59-714043f9cbca","type":"ColumnDataSource"},"glyph":{"id":"d7553ebd-dd62-4c08-ba45-3d843e0394e8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2ac70d95-df6f-4472-a959-b377d7fbcb65","type":"GlyphRenderer"},{"attributes":{},"id":"9cc9d5ad-5119-4221-b4e7-e37aac8b287c","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Male","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":[{"sex":"Male","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Male"],"smoker":["No"],"width":[0.8],"x":["Male"],"y":[10.0]}},"id":"22b84126-06eb-40bf-be59-714043f9cbca","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":130.2},"id":"d5eb796c-a180-459d-82f7-52759239b797","type":"Range1d"},{"attributes":{},"id":"021759e4-e0e9-469e-a361-1e619465c900","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"f7860ad6-c713-42ed-b2a0-d8b2b0c0f623","type":"ColumnDataSource"},"glyph":{"id":"912ab5e7-5515-4c85-83be-8de77e22cafa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4be8c073-8 ...

# %% [markdown]
# Pour avoir la version sommée à 100%, il faut manipuler en deux étapes :
#
# - créer les profils de `smoker` sur `sex`, pour chaque modalité de `time`
# - réaliser l'ensemble des diagrammes en barres empilées

# %%
tm = [pandas.melt(pandas.crosstab(t.sex, t.smoker, normalize = "index")
                  .assign(sex = t.sex.unique()), id_vars = "sex") 
      for t in [tips.query("time == '" + m + "'") for m in tips.time.unique()]]

p = layouts.column(*[Bar(tm[i], label = "sex", values = "value", 
                         stack = "smoker", title = "time: " + tips.time.unique()[i],
                         plot_height = 200) 
                    for i in range(len(tm))])

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="59386063-d5ac-48f8-9c0b-431552a9e04c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("59386063-d5ac-48f8-9c0b-431552a9e04c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("59386063-d5ac-48f8-9c0b-431552a9e04c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '59386063-d5ac-48f8-9c0b-431552a9e04c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b5210938-bfa7-4cef-a77d-bbaf5105f590":{"roots":{"references":[{"attributes":{"data_source":{"id":"d250ecd0-7c26-4bd2-b98d-aa98d9df39ed","type":"ColumnDataSource"},"glyph":{"id":"2c47e0fa-f76f-4118-85ef-5ac3cf0255f6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1c8d89c4-e802-4b75-bdd3-e77712219446","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"51659aa3-5594-40f8-a193-6dc5a291ef5e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e1902fb-49ec-4d10-a73c-0a78a4f0c2ee","type":"Rect"},{"attributes":{"data_source":{"id":"95846533-3a81-4558-bab2-d2813e393913","type":"ColumnDataSource"},"glyph":{"id":"51659aa3-5594-40f8-a193-6dc5a291ef5e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"db4d1ed9-585e-4d10-b9a1-f05c828d2b07","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Female","Male"]},"id":"d091fb7d-8c42-4326-ac25-13ba32327275","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Male","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.6209677419354839],"label":[{"sex":"Male","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Male"],"smoker":["No"],"width":[0.8],"x":["Male"],"y":[0.31048387096774194]}},"id":"3506b815-567d-455f-99b7-a6b3c2fcdf82","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"time: Lunch"},"id":"a7375257-4f43-4688-bebf-dd2fb1eda23b","type":"Title"},{"attributes":{"callback":null,"end":1.05},"id":"d61bf659-fa39-410f-a608-33f636a00d27","type":"Range1d"},{"attributes":{},"id":"f77646c0-59a4-44fe-b45b-8ba7b614a45c","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"595cb0af-0ec5-4fb1-a0a5-31c357b7da93","type":"Rect"},{"attributes":{"data_source":{"id":"3506b815-567d-455f-99b7-a6b3c2fcdf82","type":"ColumnDataSource"},"glyph":{"id":"595cb0af-0ec5-4fb1-a0a5-31c357b7da93","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2866ba5f-f4ec-4fbb-8f74-68e3f567913b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"sex":"Female","smoker":"No"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.5576923076923077],"label":[{"sex":"Female","smoker":"No"}],"line_alpha":[1.0],"line_color":["white"],"sex":["Female"],"smoker":["No"],"width":[0.8],"x":["Female"],"y":[0.27884615384615385]}},"id":"f4dd3e92-e154-4d06-ae18-21b072943138","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["Female","Male"]},"id":"e428a5ce-5fe6-46a5-b7a6-899f2a757ee4","type":"FactorRange"},{"attributes":{"data_source":{"id":"f4dd3e92-e154-4d06-ae18-21b072943138","type":"ColumnDataSource"},"glyph":{"id":"4e1902fb-49ec-4d10-a73c-0a78a4f0c2ee","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fd31bd3c-6b85-40de-9025-db350258c41e","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"abb20467-341a-4382-8555-15b8fe91d8da","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"23b5be26-5413-4c3f-9cd8-878c9753a173","type":"LinearAxis"}],"plot_height":200,"renderers":[{"id":"b4716d5a-bd69-4768-a7f3-b0f86e ...

# %% [markdown]
# ### Compléments
#
# Voici quelques paramètres généraux permettant d'améliorer les graphiques :
#
# - `title`, `xlabel`, `ylabel` : titre global et titres des axes
# - `color` : définition de couleurs (il existe aussi des palettes)
# - `plot_width` et `plot_height` : taille des figures
# - `toolbar_location` : position de la barre d'outils
#
# Il en existe d'autres, à vous de les explorer.

# %%
p = Scatter(tips, "total_bill", "tip",
            title = "Montant et pourboire en fonction du sexe",
            xlabel = "Montant total",
            ylabel = "Pourboire",
            color = color(["sex"], palette = ["blue", "orange"]),
            plot_width = 700, plot_height = 300,
            toolbar_location = "above")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aee71f90-c714-41e3-9edb-7b17421a339f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("aee71f90-c714-41e3-9edb-7b17421a339f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aee71f90-c714-41e3-9edb-7b17421a339f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aee71f90-c714-41e3-9edb-7b17421a339f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2ae1f7a-299e-4b72-b9d3-84892f6d2688":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"512b6892-7777-4f24-82e6-49dca702785c","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"},{"sex":"Female"}],"sex":["Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Female"],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[87]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[87]}}},"id":"d94e19c1-181f-47e3-b0da-36a81b5fde4e","type":"ColumnDataSource"},{"attributes":{},"id":"f5f82e2f-f87d-4871-a0b6-e203348f0d05","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8489392f-f20b-4a97-8420-ca399567efd3","subtype":"Chart","type":"Plot"},"ticker":{"id":"c366b3e2-7811-4116-8969-4298b2037f8e","type":"BasicTicker"}},"id":"00c25a01-3fdf-49c6-a40b-ad3f1a97124d","type":"Grid"},{"attributes":{"callback":null,"end":10.9,"start":0.09999999999999998},"id":"20fc1e0b-cc4d-429a-8cb8-257438e373ad","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"084325d7-64a4-4912-b28a-d45ae2b4a4dd","type":"Circle"},{"attributes":{"label":{"value":"Male"},"renderers":[{"id":"f8504417-2bc3-4f5e-8d9a-abade504f0d6","type":"GlyphRenderer"}]},"id":"0f844cff-2752-4995-8c73-f3bf1ed0bb4d","type":"LegendItem"},{"attributes":{"callback":null,"end":55.584, ...

# %% [markdown]
# ## `seaborn`
#
# Ce module, importé ci-dessous, est basé sur `matplotlib`. Il faut donc ajouter la ligne `%matplotlib inline` dans un *notebook*, pour pouvoir voir les graphiques.
#
# Ce module contient toutes les fonctions directement, l'importation est donc assez simple.

# %%
import seaborn

# %matplotlib inline

# %% [markdown]
# ### Variable quantitative
#
# La fonction `distplot()` nous permet de réaliser les graphiques de distribution d'une variable quantitative. Par défaut, elle réaliser un histogramme avec une estimation de la densité.

# %%
seaborn.distplot(tips.total_bill)

# %% [markdown]
# Pour ne garder que l'histogramme, on indique qu'on ne souhaite pas l'estimation de la densité (paramètre `kde`). Ainsi, l'histogramme devient en effectifs.

# %%
seaborn.distplot(tips.total_bill, kde = False)

# %% [markdown]
# De même, on ne peut vouloir que la densité. Auquel cas, on supprimer l'histogramme avec le paramètre `hist`.

# %%
seaborn.distplot(tips.total_bill, hist = False)

# %% [markdown]
# Il est possible de choisir le nombre de bins, avec le paramètre `bins`.

# %%
seaborn.distplot(tips.total_bill, bins = 6, kde = False)

# %% [markdown]
# Il est aussi possible de choisir les limites des intervalles, avec le même paramètre `bins`. Dans ce cas, il faut bien évidemment veiller à faire un histogramme en densité. Si on ne souhaite pas avoir l'estimation de la densité, on peut l'obtenir tout de même avec le paramètre `norm_hist`.

# %%
seaborn.distplot(tips.total_bill, bins = [0, 10, 25, 60], norm_hist = True, kde = False)

# %% [markdown]
# C'est la fonction `boxplot()` qui nous permet de réaliser une boîte à moustache (soit verticale en mettant la variable en `y`, soit horizontale en la mettant en `x`).

# %%
seaborn.boxplot(y = "total_bill", data = tips)

# %%
seaborn.boxplot(x = "total_bill", data=tips)

# %% [markdown]
# Une autre représentation possible est obtenue avec la fonction `pointplot()`, qui représente la moyenne et l'écarte-type, avec le choix entre vertical (`y`) ou horizontal (`x`).

# %%
seaborn.pointplot(y = "total_bill", data = tips)

# %%
seaborn.pointplot(x = "total_bill", data = tips)

# %% [markdown]
# Un autre graphique possible est celui obtenu avec `violinplot()`, qui représente la densité d'une variable, toujours avec le choix vertical/horizontale (`y`/`x`).

# %%
seaborn.violinplot(y = "total_bill", data = tips)

# %%
seaborn.violinplot(x = "total_bill", data = tips)

# %% [markdown]
# Enfin, il est possible de représenter toutes les valeurs sur un *pseudo* nuage de points. Avec `striplot()` dont l'option `jitter` a été activée, les points sont aléatoirement répartis sur l'axe des $x$ (si on utilise `y` - inversement sinon).

# %%
seaborn.stripplot(y = "total_bill", data = tips, jitter = True)

# %%
seaborn.stripplot(x = "total_bill", data = tips, jitter = True)

# %% [markdown]
# La fonction `factorplot()` regroupe l'ensemble des graphiques précédents (sauf l'histogramme) en une seule fonction. On accède aux différentes sous-fonctions en indiquant dans le paramètre `kind` :
#
# - `point` : moyenne +/- écart-type
# - `box` : boîte à moustaches
# - `violin` : denisté (en symétrie)
# - `strip` : *pseudo* nuage de points

# %%
seaborn.factorplot(y = "total_bill", data = tips, kind = "point")

# %% [markdown]
# ### Variable qualitative
#
# Le diagramme en barres en effectifs est obtenu via la fonction `countplot()`. Il est soit horizontal (avec la variable en `x`), soit vertical (en `y`).

# %%
seaborn.countplot(x = "sex", data = tips)

# %%
seaborn.countplot(y = "sex", data = tips)

# %% [markdown]
# Pour avoir la version en pourcentages (ou en proportions) de ce graphique, nous devons utiliser la fonction `barplot()`, sur la table de proportions calculée avant. Cette fonction réalise un calcul (moyenne par défaut) sur une variable (ici `freq`) en fonction des modalités d'une autre variable (`sex` ici donc).

# %%
t = pandas.crosstab(tips.sex, "freq", normalize=True)
t = t.assign(sex = t.index, freq = 100 * t.freq)
seaborn.barplot(x = "sex", y = "freq", data = t)

# %%
seaborn.barplot(x = "freq", y = "sex", data = t)

# %% [markdown]
# Pour réaliser un diagramme en barres empilées, il faudra le créer soi-même. Nous ne verrons pas ici.

# %% [markdown]
# Enfin, comme précédemment, la fonction `factorplot()` nous permet d'accéder aux sous-fonctions avec le choix dans `kind`.
#
# - `count` : diagramme en barres (dénombrement)
# - `bar` : diagramme en barres avec calcul

# %%
seaborn.factorplot(x = "sex", data = tips, kind = "count")

# %% [markdown]
# ### Var quantitative - Var quantitative
#
# Pour réaliser le nuage de points, on utilise la fonction `jointplot()`. Elle a l'avantage d'ajouter par défaut les histogrammes de chaque variable. Elle réalise par défaut le nuage de points simple (`scatter`). Comme pour `factorplot()`, on va pouvoir choisir le type de graphique avec le paramètre `kind`.

# %%
seaborn.jointplot(x = "total_bill", y = "tip", data = tips)

# %% [markdown]
# En choississant le type `reg`, on obtient en plus l'ajustement linéaire de la variable en `y` par celle en `x`.

# %%
seaborn.jointplot(x = "total_bill", y = "tip", data = tips, kind = "reg")

# %% [markdown]
# On peut obtenir une *heatmap*, non pas avec des rectangles mais un pavage hexagonal, avec `kind = "hex"`.

# %%
seaborn.jointplot(x = "total_bill", y = "tip", data = tips, kind = "hex")

# %% [markdown]
# Enfin, on peut avoir une estimation de la densité en 2d avec le type `kde`.

# %%
seaborn.jointplot(x = "total_bill", y = "tip", data = tips, kind = "kde")

# %% [markdown]
# Si on souhaite ne pas avoir les distributions marginales, la fonction `regplot()` nous permet de réaliser le nuage de points avec ou sans ajustement (paramètre `fit_reg`). On peut aussi n'afficher que l'ajustement.

# %%
seaborn.regplot("total_bill", "tip", data = tips, fit_reg = False)

# %%
seaborn.regplot("total_bill", "tip", data = tips)

# %%
seaborn.regplot("total_bill", "tip", data = tips, scatter = False)

# %% [markdown]
# Il est possible d'obtenir directement tous les nuages de points 2 à 2, avec la fonction `pairplot()`. Le paramètre `vars` permet de sélectionner certaines variables. Par défaut, la fonction utilise toutes les variables numériques.

# %%
seaborn.pairplot(data = tips, vars = ["total_bill", "tip", "size"])

# %% [markdown]
# ### Var qualitative - Var qualitative
#
# Pour obtenir le diagramme en barres séparées (en effectifs), nous utilisons la fonction `factorplot()` avec le paramètre `hue` (celui-ci provient de la fonction `countplot()`).

# %%
seaborn.factorplot(x = "sex", hue = "smoker", data = tips, kind = "count")

# %% [markdown]
# Cette fonction `factorplot()` permet aussi un découpage en facette avec les paramètres `row` et `col`. Ici, nous découpons donc le graphique en fonction des modalités de `smoker`.

# %%
seaborn.factorplot(x = "sex", col = "smoker", data = tips, kind = "count")

# %% [markdown]
# Pour avoir la version en pourcentages, il faut faire les calculs avant, modifier la structure du résultat et les afficher ensuite.

# %%
t = pandas.crosstab(tips.sex, tips.smoker, normalize = "columns")
t = t.assign(sex = t.index)
tm = pandas.melt(t, id_vars = "sex")
tm = tm.assign(value = 100 * tm.value)

seaborn.factorplot("sex", y = "value", col = "smoker", data = tm, kind = "bar")

# %% [markdown]
# Une autre représentation est de visualiser la table de contingence avec une *heatmap* (la couleur dépendra du nombre d'individus pour chaque couple de modalité).

# %%
seaborn.heatmap(pandas.crosstab(tips.sex, tips.smoker))

# %% [markdown]
# ### Var quantitative - Var qualitative
#
# Pour réaliser les histogrammes de la variable quantitative pour chaque modalité de la variable qualitative, il faut passer par la fonction `FacetGrid()`, permettant de faire un découpage en plusieurs lignes (avec `row`) et/ou en plusieurs colonnes (avec `col`). On applique ensuite la fonction `distplot()` avec les paramètres (ici la variable `total_bill`).

# %%
p = seaborn.FacetGrid(tips, row = "sex")
p.map(seaborn.distplot, "total_bill")

# %% [markdown]
# Les boîtes à moustaches sont elles faciles à créer avec `factorplot()` (ou `boxplot()` directement).

# %%
seaborn.factorplot(x = "sex", y = "total_bill", data = tips, kind = "box")

# %% [markdown]
# On peut aussi représenter la moyenne et l'écart-type à l'aide du graphique `pointplot`.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", data = tips, kind = "point", join = False)

# %% [markdown]
# Le graphique `violinplot` est bien sûr lui aussi applicable dans ce cas.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", data = tips, kind = "violin")

# %% [markdown]
# On a aussi la possibilité de représenter le *pseudo* nuage de points, avec `stripplot` (avec `jitter` à `True`.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", data = tips, kind = "strip", jitter = True)

# %% [markdown]
# ## Multivariables

# %% [markdown]
# #### 3 quantitatives
#
# Dans ce cas, nous cherchons à faire une *heatmap* du croisement entre les versions discrétisées en intervalles de deux variables quantitatives, la couleur d'un rectangle dépendant de la moyenne (ici `mean` du module `numpy`) d'une troisième variable. On créé la table puis l'affiche.

# %%
t = pandas.crosstab(pandas.cut(tips.total_bill, bins = 6),
                    tips["size"],
                    values = tips.tip, aggfunc = numpy.mean)
seaborn.heatmap(t)

# %% [markdown]
# #### 2 quantitatives et 1 qualitative
#
# Dans ce cas, il est possible de faire le nuage de points avec la fonction `lmplot()`, en utilisant le principe de grille (comme `factorplot()`) avec un découpage en colonnes (via `col`). On peut aussi améliorer la distinction en ajoutant une couleur différente sur la variable `sex` avec le paramètre `hue`.

# %%
seaborn.lmplot("total_bill", "tip", hue = "sex", col = "sex", data = tips)

# %% [markdown]
# #### 1 quantitative et 2 qualitatives
#
# Il est possible de créer les histogrammes de la variable quantitative pour chaque couple de modalités sur les deux variables qualitatives avec `FacetGrid()`.

# %%
p = seaborn.FacetGrid(tips, row = "sex", col = "smoker")
p.map(seaborn.distplot, "total_bill")

# %% [markdown]
# Pour les boîtes à moustaches, on utilise la fonction `factorplot()` qui permet d'ajouter une couleur en fonction d'une variable qualitative via le paramètre `hue`.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", hue = "smoker", data = tips, kind = "box")

# %% [markdown]
# Cette même fonction `factorplot()` permet le découpage en lignes (`row`) ou en colonnes (`col`), qui nous est utile pour le graphique `point`.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", hue = "smoker", col = "smoker", data = tips, 
                   kind = "point", join = False)

# %% [markdown]
# Le graphique `violin` s fait lui très facilement.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", hue = "smoker", data = tips, kind = "violin")

# %% [markdown]
# Et pour le graphique `strip`, on reprend le découpage via `col`.

# %%
seaborn.factorplot(x = "sex", y = "total_bill", hue = "smoker", col = "smoker", data = tips, 
                   kind = "strip", jitter = True)

# %% [markdown]
# #### 3 qualitatives

# %%
seaborn.factorplot(x = "sex", row = "smoker", col = "time", data = tips, kind = "count")

# %%
seaborn.factorplot(x = "sex", hue = "smoker", col = "time", data = tips, kind = "count")

# %% [markdown]
# Pour avoir la version sommée à 100%, il faut calculer la table en premier, la restructurer et l'afficher.

# %%
t = pandas.crosstab([tips.smoker, tips.time], tips.sex, normalize = "index")
t = t.assign(smoker_time = t.index)
tm = pandas.melt(t, id_vars="smoker_time")
tm = tm.assign(value = 100 * tm.value)

# %%
seaborn.factorplot(x = "smoker_time", y = "value", hue = "sex", data = tm, 
                   kind = "bar")

# %% [markdown]
# ### Compléments
#
# Il est bien évidemment possible de personnaliser le graphique de différentes façons, dont certains sont présentées ci-dessous. On accède aux fonctions de personnalisation soit via des paramètres de la fonction, soit via l'objet renvoyé par la fonction utilisée pour créer le graphique, soit via le module directement. Dans ce cas, ce sont des changements qui affecteront aussi les graphiques futurs.
#
# - `suptitle` dans `fig` : titre global
# - `set_axis_labels` : titre des axes
# - `palette` : choix d'une palette de couleurs
# - `size` et `aspect` : hauteur et ratio entre hauteur et largeur, pour chaque facette (une seule ici)

# %%
seaborn.set_style("white")
p = seaborn.factorplot(x = "size", y = "tip", hue = "sex", data = tips, kind = "box",
                      palette = "Set2", size = 4, aspect = 2)
p.fig.suptitle("Taille et pourboire en fonction du sexe")
p.set_axis_labels("Nombre de convives", "Pourboire")

# %% [markdown]
# ## A faire

# %% [markdown]
# A partir du jeu de données `Computers` présent dans le module `pydataset`, vous devez répondre aux questions suivantes, avec `bokeh` et `seaborn`. Vous pourrez trouver des informations sur ce jeu de données en exécutant `data("Computers", show_doc = True)` dans le *notebook*.

# %%
ordis = data("Computers")
ordis.head()
# Out:
#    price  speed   hd  ram  screen  cd multi premium  ads  trend
# 1   1499     25   80    4      14  no    no     yes   94      1
# 2   1795     33   85    2      14  no    no     yes   94      1
# 3   1595     25  170    4      15  no    no     yes   94      1
# 4   1849     25  170    8      14  no    no      no   94      1
# 5   3295     33  340   16      14  no    no     yes   94      1

# %%
ordis.to_csv("donnees/Computers.csv")

# %% [markdown]
# Vous pouvez télécharger le fichier [`Computers.csv`](donnees/Computers.csv), s'il n'est pas présent dans votre installation du module `pydataset`. Voici comment le charger dans `python` avec la librairie `pandas`.

# %%
ordis_csv = pandas.read_csv("donnees/Computers.csv")
ordis_csv.head()
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0           1   1499     25   80    4      14  no    no     yes   94      1
# 1           2   1795     33   85    2      14  no    no     yes   94      1
# 2           3   1595     25  170    4      15  no    no     yes   94      1
# 3           4   1849     25  170    8      14  no    no      no   94      1
# 4           5   3295     33  340   16      14  no    no     yes   94      1

# %% [markdown]
# 1. Représenter graphiquement la variable `price` (histogramme, boîte à moustaches, ...)
# 1. Représenter le lien entre la variable `price` et les variables
#     - `speed`
#     - `hd`
#     - `ram`
#     - `cd`
#     - `premium`
#     - `screen`
# 1. Représenter sur `price` l'impact de ces couples de variables
#     - `speed` et `hd`
#     - `hd` et `screen`
#     - `speed` et `premium`
#     - `hd` et `premium`
# 1. Proposer des représentations graphiques, toujours pour décrire `price` en fonction d'autres variables, mais prenant en compte plus de trois variables

# %% [markdown]
# ### `anscombe`
#
# Représenter sur un même graphique (avec un découpage donc) les quatre séries des données `anscombe`, toujours avec `bokeh` et `seaborn`.

# %%
anscombe = data("anscombe")
anscombe
# Out:
#     x1  x2  x3  x4     y1    y2     y3     y4
# 1   10  10  10   8   8.04  9.14   7.46   6.58
# 2    8   8   8   8   6.95  8.14   6.77   5.76
# 3   13  13  13   8   7.58  8.74  12.74   7.71
# 4    9   9   9   8   8.81  8.77   7.11   8.84
# 5   11  11  11   8   8.33  9.26   7.81   8.47
# 6   14  14  14   8   9.96  8.10   8.84   7.04
# 7    6   6   6   8   7.24  6.13   6.08   5.25
# 8    4   4   4  19   4.26  3.10   5.39  12.50
# 9   12  12  12   8  10.84  9.13   8.15   5.56
# 10   7   7   7   8   4.82  7.26   6.42   7.91
# 11   5   5   5   8   5.68  4.74   5.73   6.89
